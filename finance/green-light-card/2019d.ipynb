# %% [markdown]
# # 2019 Average-Daily-Balance Calculations
#
# This notebook documents months 8 through 10 for 2019.

# %%
# %run ./GreenlightUtility.py

averages = []

# %%
starting_balance = 361.12

df_csv = GreenlightUtility.get_csv_data_frame('./data/2019-08.csv')
df_csv
# Out:
#      CsvIndex       Date          Account Num    Description Memo  \
# 0  2019-08-02 2019-08-02  Greenlight Card      Spencer Gifts
# 1  2019-08-02 2019-08-02  Greenlight Card      Spencer Gifts
# 2  2019-08-03 2019-08-03  Greenlight Card            Spotify
# 3  2019-08-05 2019-08-05  Greenlight Card        Trader Joes
# 4  2019-08-12 2019-08-12  Greenlight Card         Greenlight
#
#                 Category Tag Clr  Amount
# 0      Childcare:Leisure       c  -24.24
# 1      Childcare:Leisure       c   -4.00
# 2      Childcare:Leisure       c   -9.99
# 3  Childcare:Furnishings       c   -6.48
# 4  Childcare:Furnishings       c   -4.99

# %%
df_balances = GreenlightUtility.get_balance_data_frame(df_csv, starting_balance)
df_balances
# Out:
#      CsvIndex  Balance
# 0  2019-08-02   336.88
# 1  2019-08-02   332.88
# 2  2019-08-03   322.89
# 3  2019-08-05   316.41
# 4  2019-08-12   311.42

# %%
df_eod_balances = GreenlightUtility.get_balance_eod_data_frame(df_balances)
df_eod_balances
# Out:
#             Balance
# CsvIndex
# 2019-08-02   332.88
# 2019-08-03   322.89
# 2019-08-05   316.41
# 2019-08-12   311.42

# %%
first_day_of_month = GreenlightUtility.get_first_day_of_month(2019, 8)

df_daily_balance = GreenlightUtility.get_daily_balance_data_frame(
    first_day_of_month,
    starting_balance,
    df_eod_balances)

averages.append((first_day_of_month.strftime('%Y-%m'), df_daily_balance.mean().values[0]))

# %%
df_eod_balances.tail(1)
# Out:
#             Balance
# CsvIndex
# 2019-08-12   311.42

# %% [markdown]
# ## 2019-9

# %%
starting_balance = 311.42

df_csv = GreenlightUtility.get_csv_data_frame('./data/2019-09.csv')
df_csv
# Out:
#      CsvIndex       Date          Account Num     Description            Memo  \
# 0  2019-09-02 2019-09-02  Greenlight Card      Transfer Money
# 1  2019-09-03 2019-09-03  Greenlight Card             Spotify
# 2  2019-09-03 2019-09-03  Greenlight Card               Apple
# 3  2019-09-07 2019-09-07  Greenlight Card              Google  YouTube videos
# 4  2019-09-08 2019-09-08  Greenlight Card                 CVS
# 5  2019-09-12 2019-09-12  Greenlight Card          Greenlight
# 6  2019-09-22 2019-09-22  Greenlight Card      Transfer Money
# 7  2019-09-26 2019-09-26  Greenlight Card              Google  YouTube videos
#
#                 Category Tag Clr  Amount
# 0       [inflow account]       c   50.00
# 1      Childcare:Leisure       c   -9.99
# 2      Childcare:Leisure       c   -5.99
# 3      Childcare:Leisure       c   -1.99
# 4  Childcare:Furnishings       c  -14.26
# 5  Childcare:Furnishings           -4.99
# 6       [inflow account]          130.00
# 7      Childcare:Leisure       c   -3.99

# %%
df_balances = GreenlightUtility.get_balance_data_frame(df_csv, starting_balance)
df_balances
# Out:
#      CsvIndex  Balance
# 0  2019-09-02   361.42
# 1  2019-09-03   351.43
# 2  2019-09-03   345.44
# 3  2019-09-07   343.45
# 4  2019-09-08   329.19
# 5  2019-09-12   324.20
# 6  2019-09-22   454.20
# 7  2019-09-26   450.21

# %%
df_eod_balances = GreenlightUtility.get_balance_eod_data_frame(df_balances)
df_eod_balances
# Out:
#             Balance
# CsvIndex
# 2019-09-02   361.42
# 2019-09-03   345.44
# 2019-09-07   343.45
# 2019-09-08   329.19
# 2019-09-12   324.20
# 2019-09-22   454.20
# 2019-09-26   450.21

# %%
first_day_of_month = GreenlightUtility.get_first_day_of_month(2019, 9)

df_daily_balance = GreenlightUtility.get_daily_balance_data_frame(
    first_day_of_month,
    starting_balance,
    df_eod_balances)

averages.append((first_day_of_month.strftime('%Y-%m'), df_daily_balance.mean().values[0]))

# %%
df_eod_balances.tail(1)
# Out:
#             Balance
# CsvIndex
# 2019-09-26   450.21

# %% [markdown]
# ## 2019-10

# %%
starting_balance = 450.21

df_csv = GreenlightUtility.get_csv_data_frame('./data/2019-10.csv')
df_csv
# Out:
#      CsvIndex       Date          Account Num      Description Memo  \
# 0  2019-10-01 2019-10-01  Greenlight Card       Transfer Money
# 1  2019-10-02 2019-10-02  Greenlight Card                Apple
# 2  2019-10-03 2019-10-03  Greenlight Card      Barnes & Nobles
# 3  2019-10-03 2019-10-03  Greenlight Card                Apple
# 4  2019-10-12 2019-10-12  Greenlight Card           Greenlight
# 5  2019-10-14 2019-10-14  Greenlight Card                Apple
# 6  2019-10-18 2019-10-18  Greenlight Card         Campos Tacos
#
#                 Category Tag Clr  Amount
# 0       [inflow account]          150.00
# 1      Childcare:Leisure       c  -10.97
# 2  Childcare:Furnishings       c  -21.85
# 3      Childcare:Leisure       c   -5.99
# 4  Childcare:Furnishings           -4.99
# 5      Childcare:Leisure       c   -0.99
# 6  Childcare:Furnishings       c  -12.59

# %%
df_balances = GreenlightUtility.get_balance_data_frame(df_csv, starting_balance)
df_balances
# Out:
#      CsvIndex  Balance
# 0  2019-10-01   600.21
# 1  2019-10-02   589.24
# 2  2019-10-03   567.39
# 3  2019-10-03   561.40
# 4  2019-10-12   556.41
# 5  2019-10-14   555.42
# 6  2019-10-18   542.83

# %%
df_eod_balances = GreenlightUtility.get_balance_eod_data_frame(df_balances)
df_eod_balances
# Out:
#             Balance
# CsvIndex
# 2019-10-01   600.21
# 2019-10-02   589.24
# 2019-10-03   561.40
# 2019-10-12   556.41
# 2019-10-14   555.42
# 2019-10-18   542.83

# %%
first_day_of_month = GreenlightUtility.get_first_day_of_month(2019, 10)

df_daily_balance = GreenlightUtility.get_daily_balance_data_frame(
    first_day_of_month,
    starting_balance,
    df_eod_balances)

averages.append((first_day_of_month.strftime('%Y-%m'), df_daily_balance.mean().values[0]))

# %%
df_eod_balances.tail(1)
# Out:
#             Balance
# CsvIndex
# 2019-10-18   542.83

# %% [markdown]
# ## Calculation of Contribution

# %%
df_final = GreenlightUtility.get_final_data_frame(averages)
df_final
# Out:
#      Dates     Balance
# 0  2019-08  315.582258
# 1  2019-09  367.488667
# 2  2019-10  554.070000

# %%
df_final['Balance'].sum() * .1
# Out:
# 123.71409247311827
