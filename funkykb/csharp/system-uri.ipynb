# %% [markdown]
# # `System.Uri`
#
# There are the leading remarks (warnings) about `System.Uri`:
#
# 1. when constructing, the `UriKind` argument is often required
# 2. relative <acronym title="Universal Resource Identifier">URI</acronym>s invalidate almost every public member
# 3. `Uri.Segments` are punctuated by a trailing forward slash

# %% [markdown]
# ## when constructing, the `UriKind` argument is often required

# %%
new Uri("./my/file/is/here.txt")
# Out:
# System.UriFormatException: Invalid URI: The format of the URI could not be determined.
#
#    at System.Uri.CreateThis(String uri, Boolean dontEscape, UriKind uriKind, UriCreationOptions& creationOptions)
#
#    at System.Uri..ctor(String uriString)
#
#    at Submission#1.<<Initialize>>d__0.MoveNext()
#
# --- End of stack trace from previous location ---
#
#    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

# %% [markdown]
# ## relative <acronym title="Universal Resource Identifier">URI</acronym>s invalidate almost every public member

# %%
var relative = new Uri("./my/file/is/here.txt", UriKind.Relative);

relative
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>./my/file/is/here.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AbsolutePath</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.InvalidOperationException: This operation is not supported for a relative URI.\n   at System.Uri.get_AbsolutePath()\n   at lambda_method301(Closure, Uri)\n   at Microsoft.DotNet.Interactive.Formatting.MemberAccessor`1.GetValueOrException(T instance) in D:\a\_work\1\s\src\Microsoft.DotNet.Inte...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>TargetSite</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.String get_AbsolutePath()</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>get_AbsolutePath</pre></div></td></tr><tr><td>DeclaringType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.uri?view=net-7.0">System.Uri</a></span></td></tr><tr><td>ReflectedType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.uri?view=net-7.0">System.Uri</a></span></td></tr><tr><td>MemberType</td><td><span>Method</span></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>100663363</pre></div></td></tr><tr><td>Module</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.Uri.dll</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>MDStreamVersion</td><td><div class="dni-plaintext"><pre>131072</pre></div></td></tr><tr><td>FullyQualifiedName</td><td><div class="dni-plaintext"><pre>/usr/share/dotnet/shared/Microsoft.NETCore.App/9.0.4/System.Private.Uri.dll</pre></div></td></tr><tr><td>ModuleVersionId</td><td><div class="dni-plaintext"><pre>99e8631d-7754-4c1f-a06d-8fa521bccc3a</pre></div></td></tr><tr><td>MetadataToken</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ScopeName</td><td><div class="dni-plaintext"><pre>System.Private.Uri.dll</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>System.Private.Uri.dll</pre></div></td></tr><tr><td>Assembly</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>System.Private.Uri, Version=9.0.0.0, Culture=neutral, PublicKeyToken=b03f5f7f11d50a3a</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>CodeBase</td><td><div class="dni-plaintext"><pre>file:///usr/share/dotnet/shared/Microsoft.NETCore.App/9.0.4/System.Private.Uri.dll</pre></div></td></tr><tr><td>FullName</td><td><div class="dni-plaintext"><pre>System.Private.Uri, Version=9.0.0.0, Culture=neutral, PublicKeyToken=b03f5f7f11d50a3a</pre></div></td></tr><tr><td>EntryPoint</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>DefinedTypes</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>FxResources.System.Private.Uri.SR</td></tr><tr><td>1</td><td>System.HexConverter</td></tr><tr><td>2</td><td>System.HexConverter+Casing</td></tr><tr><td>3</td><td>System.DomainNameHelper</td></tr><tr><td>4</td><td>System.GenericUriParserOptions</td></tr><tr><td>5</td><td>System.GenericUriParser</td></tr><tr><td>6</td><td>System.IPv4AddressHelper</td></tr><tr><td>7</td><td>System.IPv6AddressHelper</td></tr><tr><td>8</td><td>System.IriHelper</td></tr><tr><td>9</td><td>System.PercentEncodingHelper</td></tr><tr><td>10</td><td>System.UncNameHelper</td></tr><tr><td>11</td><td>System.Uri</td></tr><tr><td>12</td><td>System.Uri+Flags</td></tr><tr><td>13</td><td>System.Uri+UriInfo</td></tr><tr><td>14</td><td>System.Uri+Offset</td></tr><tr><td>15</td><td>System.Uri+MoreInfo</td></tr><tr><td>16</td><td>System.Uri+Check</td></tr><tr><td>17</td><td>System.Uri+<>c</td></tr><tr><td>18</td><td>System.UriBuilder</td></tr><tr><td>19</td><td>System.UriCreationOptions</td></tr><tr><td colspan="2"><i>(28 more)< ...

# %% [markdown]
# As an exotic, self-defeating workaround, we can prepend [the file scheme](https://en.wikipedia.org/wiki/File_URI_scheme) to our relative-URI `OriginalString`:

# %%
var absolute = new Uri("file:///my/file/is/here.txt");

absolute
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>file:///my/file/is/here.txt</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>AbsolutePath</td><td><div class="dni-plaintext"><pre>/my/file/is/here.txt</pre></div></td></tr><tr><td>AbsoluteUri</td><td><div class="dni-plaintext"><pre>file:///my/file/is/here.txt</pre></div></td></tr><tr><td>LocalPath</td><td><div class="dni-plaintext"><pre>/my/file/is/here.txt</pre></div></td></tr><tr><td>Authority</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>HostNameType</td><td><span>Basic</span></td></tr><tr><td>IsDefaultPort</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IsFile</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IsLoopback</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>PathAndQuery</td><td><div class="dni-plaintext"><pre>/my/file/is/here.txt</pre></div></td></tr><tr><td>Segments</td><td><div class="dni-plaintext"><pre>[ /, my/, file/, is/, here.txt ]</pre></div></td></tr><tr><td>IsUnc</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Host</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Port</td><td><div class="dni-plaintext"><pre>-1</pre></div></td></tr><tr><td>Query</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Fragment</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Scheme</td><td><div class="dni-plaintext"><pre>file</pre></div></td></tr><tr><td>OriginalString</td><td><div class="dni-plaintext"><pre>file:///my/file/is/here.txt</pre></div></td></tr><tr><td>DnsSafeHost</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>IdnHost</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>IsAbsoluteUri</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>UserEscaped</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>UserInfo</td><td><div class="dni-plaintext"><pre></pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# ## `Uri.Segments` are punctuated by a trailing forward slash

# %% [markdown]
# We see in our file-scheme absolute URI above that the `Uri.Segments` end with a forward slash:

# %%
absolute.Segments
# Out:
# <div class="dni-plaintext"><pre>[ /, my/, file/, is/, here.txt ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# This output is likely unexpected when one might use the `String.Split` method [📖 [docs](https://learn.microsoft.com/en-us/dotnet/api/system.string.split)] like this:

# %%
absolute.AbsolutePath.Trim('/').Split('/')
# Out:
# <div class="dni-plaintext"><pre>[ my, file, is, here.txt ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# About once a year, I forget about the `Uri.Segments` conventions and trick myself into thinking that using `String.Split` on `AbsolutePath` or maybe `OriginalString` is redundant and betrays my ignorance of the members of `System.Uri`. This note should remind me that I should  prefer using `String.Split`.

# %% [markdown]
# ## <!-- -->
#
# [Bryan Wilhite is on LinkedIn](https://www.linkedin.com/in/wilhite)🇺🇸💼
