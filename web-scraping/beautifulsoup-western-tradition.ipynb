# %% [markdown]
# # The Western Tradition (1989)
#
# <https://thetvdb.com/series/the-western-tradition>
#
# ![The Western Tradition poster](https://artworks.thetvdb.com/banners/posters/83781-1.jpg)

# %% [markdown]
# These notes preserve my memories of auto-generating [Kodi](https://kodi.tv/) [[GitHub](https://github.com/xbmc)] `tvshow` and `episodedetails` XML files in `*.nfo` formats.
#
# This `*.nfo` format is kind of covered in the following documents:
#
# - [NFO files](https://kodi.wiki/view/NFO_files)
# - [NFO files/TV shows](https://kodi.wiki/view/NFO_files/TV_shows)
# - [NFO files/Episodes](https://kodi.wiki/view/NFO_files/Episodes)

# %%
from IPython.display import display, HTML

import songhay.utilities.elementtree as ET
import songhay.utilities.soup as bs

import songhay.soup.thetvdb.series as series

# %% [markdown]
# ## generating `tvshow` data

# %%
series_location = 'https://thetvdb.com/series/the-western-tradition'
series_soup = bs.getSoup(series_location)

series_basic_info = dict(series.yieldSeriesBasicInfo(series_soup))

series_data = dict(
    uniqueids=[
        {
            'type': 'tvdb',
            'uniqueid': 'series/the-western-tradition'
        },
        {
            'type': 'imdb',
            'uniqueid': 'tt7106818'
        },
    ],
    title=series.getSeriesTitle(series_soup),
    plot=series.getSeriesPlot(series_soup),
    thumbs=[
        {
            'aspect': 'poster',
            'dim': None,
            'season': None, # maps to the top-level movie poster
            'src': 'https://artworks.thetvdb.com/banners/posters/83781-1.jpg'
        },
    ],
    genres=series_basic_info['Genres'],
    actors=[]
)

ET.getTVShowXmlTree(series_data).write(
    './beautifulsoup-the-western-tradition/tvshow.nfo',
    encoding='utf-8',
    xml_declaration=True)

# %% [markdown]
# ## generating `episodedetails` data

# %%
episode_location = 'https://thetvdb.com/series/the-western-tradition/seasons/official/1'

dvd_episode_soup = bs.getSoup(episode_location)
table = dvd_episode_soup.find('table')

display(HTML(table.decode()))
# Out:
# <table class="table table-bordered">
# <thead>
# <tr>
# <th width="15%"></th>
# <th>Name</th>
# <th width="30%">First Aired</th>
# <th width="15%">Runtime</th>
# <th width="10%">Image</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>S01E01</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407397">
#                                         The Dawn of History
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E02</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407398">
#                                         The Ancient Egyptians
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E03</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407399">
#                                         Mesopotamia
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E04</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407400">
#                                         From Bronze to Iron
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E05</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407401">
#                                         The Rise of Greek Civilization
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E06</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407402">
#                                         Greek Thought
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E07</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407403">
#                                         Alexander the Great
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E08</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407404">
#                                         The Hellenistic Age
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E09</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407405">
#                                         The Rise of Rome
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E10</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407406">
#                                         The Roman Empire
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E11</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407407">
#                                         Early Christianity
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E12</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407408">
#                                         The Rise of the Church
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E13</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407409">
#                                         The Decline of Rome
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E14</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407410">
#                                         The Fall of Rome
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E15</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407411">
#                                         The Byzantine Empire
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E16</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407412">
#                                         The Fall of Byzantium
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E17</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407413">
#                                         The Dark Ages
#                                     </a>
# </td>
# <td>
# <div>January 1, 1989</div>
# </td>
# <td>
#                                                                             30
#                                                                     </td>
# <td>
# <i aria-hidden="true" class="fa fa-picture-o"></i>
# </td>
# </tr>
# <tr>
# <td>S01E18</td>
# <td>
# <a href="/series/the-western-tradition/episodes/407414">

# %%
import songhay.soup.thetvdb.episode as episode

episode_data = list(episode.yieldEpisodeData(table))
episode_data
# Out:
# [{'episode': 'S01E01',
#   'title': 'The Dawn of History',
#   'plot': 'The origins of the human race are traced from anthropoid ancestors to the agricultural revolution.',
#   'year': '1989'},
#  {'episode': 'S01E02',
#   'title': 'The Ancient Egyptians',
#   'plot': 'Egyptian irrigation created one of the first great civilizations.',
#   'year': '1989'},
#  {'episode': 'S01E03',
#   'title': 'Mesopotamia',
#   'plot': 'Settlements in the Fertile Crescent gave rise to the great river civilizations of the Middle East.',
#   'year': '1989'},
#  {'episode': 'S01E04',
#   'title': 'From Bronze to Iron',
#   'plot': 'Metals revolutionized tools, as well as societies, in the empires of Assyria, Persia, and Neo-Babylonia.',
#   'year': '1989'},
#  {'episode': 'S01E05',
#   'title': 'The Rise of Greek Civilization',
#   'plot': 'Democracy and philosophy arose from Greek cities at the edge of the civilized world.',
#   'year': '1989'},
#  {'episode': 'S01E06',
#   'title': 'Greek Thought',
#   'plot': 'Socrates, Plato, and Aristotle laid the foundation of Western intellectual thought.',
#   'year': '1989'},
#  {'episode': 'S01E07',
#   'title': 'Alexander the Great',
#   'plot': "Alexander's conquests quadrupled the size of the world known to the Greeks.",
#   'year': '1989'},
#  {'episode': 'S01E08',
#   'title': 'The Hellenistic Age',
#   'plot': 'Hellenistic kingdoms extended Greek culture throughout the Mediterranean.',
#   'year': '1989'},
#  {'episode': 'S01E09',
#   'title': 'The Rise of Rome',
#   'plot': 'Through its army, Rome built an empire that shaped the West.',
#   'year': '1989'},
#  {'episode': 'S01E10',
#   'title': 'The Roman Empire',
#   'plot': "Rome's civil engineering contributed as much to the empire as did its weapons.",
#   'year': '1989'},
#  {'episode': 'S01E11',
#   'title': 'Early Christianity',
#   'plot': 'Christianity spread despite contempt and persecution from Rome.',
#   'year': '1989'},
#  {'episode': 'S01E12',
#   'title': 'The Rise of the Church',
#   'plot': "The old heresy became the Roman empire's official religion under the Emperor Constantine.",
#   'year': '1989'},
#  {'episode': 'S01E13',
#   'title': 'The Decline of Rome',
#   'plot': "While enemies slashed at Rome's borders, civil war and economic collapse destroyed the empire from within.",
#   'year': '1989'},
#  {'episode': 'S01E14',
#   'title': 'The Fall of Rome',
#   'plot': 'Despite the success of emperors such as Hadrian and Marcus Aurelius, Rome fell victim to barbarian invasions.',
#   'year': '1989'},
#  {'episode': 'S01E15',
#   'title': 'The Byzantine Empire',
#   'plot': 'From Constantinople, the Byzantine Empire carried on the traditions of Greece and Rome.',
#   'year': '1989'},
#  {'episode': 'S01E16',
#   'title': 'The Fall of Byzantium',
#   'plot': "Nearly a thousand years after Rome's fall, Constantinople was conquered by the forces of Islam.",
#   'year': '1989'},
#  {'episode': 'S01E17',
#   'title': 'The Dark Ages',
#   'plot': 'Barbarian kingdoms took possession of the fragments of the Roman Empire.',
#   'year': '1989'},
#  {'episode': 'S01E18',
#   'title': 'The Age of Charlemagne',
#   'plot': 'Charlemagne revived hopes for a new empire in Western Europe.',
#   'year': '1989'},
#  {'episode': 'S01E19',
#   'title': 'The Middle Ages',
#   'plot': 'Amid invasion and civil disorder, a military aristocracy dominated the kingdoms of Europe.',
#   'year': '1989'},
#  {'episode': 'S01E20',
#   'title': 'The Feudal Order',
#   'plot': 'Bishop, knight, and peasant exemplified some of the social divisions of the year 1000 A.D.',
#   'year': '1989'},
#  {'episode': 'S01E21',
#   'title': 'Common Life in the Middle Ages',
#   'plot': 'Famine, disease, and short life expectancies were the conditions that shaped medieval beliefs.',
#   'year': '1989'},
#  {'episode': 'S01E22',
#   'title': 'Cities and Cathedrals of the Middle Ages',
#   'plot': 'The great churches embodied the material and spiritual ambitions of the age.',
#   'year': '1989'},
#  {'episode': 'S01E23',
#   'title': 'The Late Middle Ages',
#   'plot': 'Two hundred years of war and plague debilitated Europe.',
#   'year': '1989'},
#  {'episode': 'S01E24',
#   'title': 'The National Monarchies',
#   'plot': 'A new urban middle class emerged, while dynastic marriages established centralized monarchies.',
#   'year': '1989'},
#  {'episode': 'S01E25',
#   'title': 'Renaissance & the Age of Discovery',
#   'plot': 'Renaissance humanists made man "the measure of all things." Europe was possessed by a new passion for knowledge.',
#   'year': '1989'},
#  {'episode': 'S01E26',
#   'title': 'Renaissance & the New World',
#   'plot': 'The discovery of America challenged Europe.',
#   'year': '1989'},
#  {'episode': 'S01E27',
#   'title': 'The Reformation',
#   'plot': 'Voiced by Martin Luther, Protestantism shattered the unity of the Catholic Church.',
#   'year': '1989'},
#  {'episode': 'S01E28',
#   'title': 'The Rise of the Middle Class',
#   'plot': 'As the cities grew, new middle-class mores had an impact on religious life.',
#   'year': '1989'},
#  {'episode': 'S01E29',
#   'title': 'The Wars of Religion',
#   'plot': 'For more than a century, the quarrels of Protestants and Catholics tore Europe apart.',
#   'year': '1989'},
#  {'episode': 'S01E30',
#   'title': 'The Rise of the Trading Cities',
#   'plot': 'Amid religious wars, a few cities learned that tolerance increased their prosperity.',
#   'year': '1989'},
#  {'episode': 'S01E31',
#   'title': 'The Age of Absolutism',
#   'plot': 'Exhausted by war and civil strife, many Europeans exchanged earlier liberties and anarchies for greater peace.',
#   'year': '1989'},
#  {'episode': 'S01E32',
#   'title': 'Absolutism and the Social Contract',
#   'plot': 'Arguments about the legitimate source of political power centered on divine right versus natural law.',
#   'year': '1989'},
#  {'episode': 'S01E33',
#   'title': 'The Enlightened Despots',
#   'plot': 'Monarchs considered reforms in order to create more efficient societies, but not at the expense of their own power.',
#   'year': '1989'},
#  {'episode': 'S01E34',
#   'title': 'The Enlightenment',
#   'plot': 'Intellectual theories about the nature of man and his potential came to the fore.',
#   'year': '1989'},
#  {'episode': 'S01E35',
#   'title': 'The Enlightenment and Society',
#   'plot': 'Scientists and social reformers battled for universal human rights during a peaceful and prosperous period.',
#   'year': '1989'},
#  {'episode': 'S01E36',
#   'title': 'The Modern Philosophers',
#   'plot': 'Freedom of thought and expression opened new vistas explored by French, English, and American thinkers.',
#   'year': '1989'},
#  {'episode': 'S01E37',
#   'title': 'The American Revolution',
#   'plot': 'The British colonists created a society that tested Enlightenment ideas and resisted restrictions imposed by England.',
#   'year': '1989'},
#  {'episode': 'S01E38',
#   'title': 'The American Republic',
#   'plot': 'A new republic, the compromise of radicals and conservatives, was founded on universal freedoms.',
#   'year': '1989'},
#  {'episode': 'S01E39',
#   'title': 'The Death of the Old Regime',
#   'plot': "In France the old order collapsed under revolutionaries' attacks and the monarchy's own weakness.",
#   'year': '1989'},
#  {'episode': 'S01E40',
#   'title': 'The French Revolution',
#   'plot': 'Liberty, equality, and fraternity skidded into a reign of Terror.',
#   'year': '1989'},
#  {'episode': 'S01E41',
#   'title': 'The Industrial Revolution',
#   'plot': 'Technology and mass production reduced famine and ushered in higher standards of living.',
#   'year': '1989'},
#  {'episode': 'S01E42',
#   'title': 'The Industrial World',
#   'plot': 'A consumer revolution was fueled by coal, public transportation, and new city services.',
#   'year': '1989'},
#  {'episode': 'S01E43',
#   'title': 'Revolution and Romantics',
#   'plot': 'Leaders in the arts, literature, and political theory argued for social justice and national liberation.',
#   'year': '1989'},
#  {'episode': 'S01E44',
#   'title': 'The Age of the Nation-States',
#   'plot': 'The great powers cooperated to quell internal revolts, yet competed to acquire colonies.',
#   'year': '1989'},
#  {'episode': 'S01E45',
#   'title': 'A New Public',
#   'plot': 'Public education and mass communications created a new political life and leisure time.',
#   'year': '1989'},
#  {'episode': 'S01E46',
#   'title': 'Fin de Siècle',
#   'plot': 'Everyday life of the working class was transformed by leisure, prompting the birth of an elite avant-garde movement.',
#   'year': '1989'},
#  {'episode': 'S01E47',
#   'title': 'The First World War and the Rise of Fascism',
#   'plot': 'Old empires crumbled during World War I to be replaced by right-wing dictatorships in Italy, Spain, and Germany.',
#   'year': '1989'},
#  {'episode': 'S01E48',
#   'title': 'The Second World War',
#   'plot': 'World War II was a war of new tactics and strategies. Civilian populations became targets as the Nazi holocaust exterminated millions of people.',
#   'year': '1989'},
#  {'episode': 'S01E49',
#   'title': 'The Cold War',
#   'plot': 'The U.S. and Soviet Union dominated Europe and confronted each other in Korea.',
#   'year': '1989'},
#  {'episode': 'S01E50',
#   'title': 'Europe and the Third World',
#   'plot': 'Burdened with the legacy of colonial imperialism, the Third World rushed development to catch up with its Western counterparts.',
#   'year': '1989'},
#  {'episode': 'S01E51',
#   'title': 'The Technological Revolution',
#   'plot': 'Keeping up with the ever-increasing pace of change became the standard of the day.',
#   'year': '1989'},
#  {'episode': 'S01E52',
#   'title': 'Toward the Future',
#   'plot': 'Modern medicine, atomic energy, computers, and new concepts of time, energy, and matter all have an important effect on life in the 20th century.',
#   'year': '1989'}]

# %%
nfo_location_template = f"./beautifulsoup-the-western-tradition/{series_data['title']}"

# %%
for item in episode_data:
    episode = item['episode']
    year = item['year']
    xml_tree = ET.getEpisodeDetailsXmlTree(item['title'], item['plot'])
    ET.writeEpisodeDetailsXml(nfo_location_template, episode, year, xml_tree)

# %% [markdown]
# [Bryan Wilhite is on LinkedIn](https://www.linkedin.com/in/wilhite)🇺🇸💼
